# %%
n = int(input())

for _ in range(n):
  cnt, word = input().split()
  for i in word:
    print(i * int(cnt), end = '') # end = ' ' 옆으로 붙임
  print() # 줄넘김
# Out:
# 2
# 3 ABC
# AAABBBCCC
# 5 /HTP
# /////HHHHHTTTTTPPPPP
