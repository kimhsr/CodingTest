# %%
t = int(input())

for i in range(t):
  a, b = map(int, input().split())
  print(f"Case #{i+1}: {a} + {b} = {a+b}")
# Out:
# 5
# 1 1
# Case #1: 1 + 1 = 2
# 2 3
# Case #2: 2 + 3 = 5
# 3 4
# Case #3: 3 + 4 = 7
# 9 8
# Case #4: 9 + 8 = 17
# 5 2
# Case #5: 5 + 2 = 7
