# %%
n = int(input())

for i in range(n):
  a = list(input())
  count = 0
  sum = 0

  for i in a:
    if i == 'O':
      count += 1
      sum += count
    else:
      count = 0
      
  print(sum)
# Out:
# 5
# OOXXOXXOOO
# 10
# OOXXOOXXOO
# 9
# OXOXOXOXOXOXOX
# 7
# OOOOOOOOOO
# 55
# OOOOXOOOOXOOOOX
# 30
