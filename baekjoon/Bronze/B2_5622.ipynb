# %%
alphabet = ['ABC', 'DEF', 'GHI', 'JKL', 'MNO', 'PQRS', 'TUV', 'WXYZ']
word = input()

time = 0
for unit in alphabet:
  for i in unit: # alphabet 리스트에서 각 요소를 꺼내서 한글자씩 분리
    for x in word:
      if i == x:
        time += alphabet.index(unit) + 3

print(time)
# Out:
# UNUCIC
# 36
