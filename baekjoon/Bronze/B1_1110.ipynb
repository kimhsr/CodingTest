# %%
n = int(input())
num = n
cnt = 0

# 84 입력 받을 경우
while True:
  a = num // 10        # 84 // 10 = 8
  b = num % 10         # 84 % 10 = 4
  c = (a + b) % 10     # 12 % 10 = 2
  num = (b * 10) + c   # 40 + 2 = 42

  cnt += 1
  if num == n:
    break

print(cnt)
# Out:
# 55
# 3
