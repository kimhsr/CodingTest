# %%
a = [10,20,30,40,50,60,70,80,90]
print(a[3])
print(a[-5])
print(a[:7:2])
print(a[:7:3])
print(a[3:])
print(a[:5])
# Out:
# 40
# 50
# [10, 30, 50, 70]
# [10, 40, 70]
# [40, 50, 60, 70, 80, 90]
# [10, 20, 30, 40, 50]
