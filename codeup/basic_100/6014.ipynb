# %%
a = float(input())
print(\)
# Out:
#   File "<ipython-input-1-0c8741a49189>", line 2
#     print(a\na\na)
#                   ^
# SyntaxError: unexpected character after line continuation character
