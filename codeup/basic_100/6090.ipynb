# %%
a, m, d, n = map(int, input().split())

for i in (n - 1):
  a = (a * m) + d

print(a)
# Out:
# 1 -2 1 8
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-1e6d21f156fd> in <module>()
#       1 a, m, d, n = map(int, input().split())
#       2
# ----> 3 for i in (n - 1):
#       4   a = (a * m) + d
#       5
#
# TypeError: 'int' object is not iterable
