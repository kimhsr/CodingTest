# %%
a = int(input)
print(a)
print(b)
# Out:
# 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-c0afcf4eed86> in <module>()
# ----> 1 a, b = int(input())
#       2 print(a)
#       3 print(b)
#
# TypeError: cannot unpack non-iterable int object
