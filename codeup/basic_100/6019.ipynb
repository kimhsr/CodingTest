# %%
y, m, d = map(int, input().split('.'))

print(d, m, y, sep='-')
# Out:
# 2020.3.4
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e8262be0bc0f> in <module>()
#       1 y, m, d = map(int, input().split('.'))
#       2
# ----> 3 print(d, m, y, sep('-'))
#
# NameError: name 'sep' is not defined
